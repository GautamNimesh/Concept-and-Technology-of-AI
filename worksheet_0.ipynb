# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #Exercise 7:
# Task 1. Classify Study Time:

# %%
# Daily time (in hours): [study, entertainment, sleep]
time_data = [
(3.5, 2.0, 7.0), (5.0, 1.5, 6.5), (2.5, 3.0, 8.0),
(4.0, 2.0, 6.0), (1.5, 4.5, 9.0), (3.0, 2.5, 7.5),
(5.5, 1.0, 6.0), (2.0, 3.5, 8.5), (4.5, 2.0, 7.0),
(3.0, 3.0, 7.5), (6.0, 1.5, 6.0), (2.5, 4.0, 8.0),
(4.0, 2.5, 7.0), (5.0, 2.0, 6.5), (3.5, 2.5, 7.0)
]

# %%
low = []
moderate = []
high = []

# %%
for data in time_data:
  study_hour = data[0]
  if study_hour < 3:
    low.append(study_hour)
  elif 3 <= study_hour <= 5:
    moderate.append(study_hour)
  else:
    high.append(study_hour)

# %%
print("Low study hours:", low)
print("Moderate study hours:", moderate)
print("High study hours:", high)
# Out:
# Low study hours: [2.5, 1.5, 2.0, 2.5]
# Moderate study hours: [3.5, 5.0, 4.0, 3.0, 4.5, 3.0, 4.0, 5.0, 3.5]
# High study hours: [5.5, 6.0]

# %% [markdown]
# Task 2.

# %% [markdown]
# Question_1. How many days had low study time?

# %%
low_days = len(low)
print("Days with low study time:", low_days)
# Out:
# Days with low study time: 4

# %% [markdown]
# Question_2. How many days had moderate study time?

# %%
moderate_days = len(moderate)
print("Days with moderate study time:", moderate_days)
# Out:
# Days with moderate study time: 9

# %% [markdown]
# Question_3. How many days had high study time?

# %%
high_days = len(high)
print("Days with high study time:", high_days)
# Out:
# Days with high study time: 2

# %% [markdown]
# Task 3. Convert Study Hours to Minutes:

# %%
study_minutes = []

# %%
for min_data in time_data:
  study_hour = min_data[0]
  study_min = study_hour * 60
  study_minutes.append(study_min)

# %%
print("Converted Study hours in minute: ", study_minutes)
# Out:
# Converted Study hours in minute:  [210.0, 300.0, 150.0, 240.0, 90.0, 180.0, 330.0, 120.0, 270.0, 180.0, 360.0, 150.0, 240.0, 300.0, 210.0]

# %% [markdown]
# Task 4. Analyze Average Time Use:

# %%
study_hrs=[]
entertainment_hrs =[]
sleep_hrs =[]

# %%
for data in time_data:
  study_hour = data[0]
  entertainment_hour = data[1]
  sleep_hour = data[2]

# %%
study_hrs.append(study_hour)
entertainment_hrs.append(entertainment_hour)
sleep_hrs.append(sleep_hour)

# %%
study_avg = np.mean(study_hrs)
entertainment_avg = np.mean(entertainment_hrs)
sleep_avg = np.mean(sleep_hrs)

# %%
print("Average study hours = ", study_avg)
print("Average entertainment hours = ", entertainment_avg)
print("Average sleep hours = ", sleep_avg)
# Out:
# Average study hours =  3.5
# Average entertainment hours =  2.5
# Average sleep hours =  7.0

# %% [markdown]
# Task 5. Visualization - Study vs Sleep Pattern:

# %%
study_hrs = []
sleep_hrs = []

# %%
for data in time_data:
  study_hour = data[0]
  sleep_hour = data[2]
  study_hrs.append(study_hour)
  sleep_hrs.append(sleep_hour)

# %%
plt.figure(figsize=(10, 6))
plt.scatter(study_hrs, sleep_hrs, color = 'orange', marker = 'o')
plt.xlabel("Study Hours")
plt.ylabel("Sleep Hours")
plt.title("Study vs Sleep Pattern")
plt.grid(True)
plt.xlim(1,7)
plt.ylim(4,10)
plt.show()

# %% [markdown]
# #Exercise 8:
# Task 1 - Sum of Nested Lists:

# %%
def sum_nested_list(nested_list):
  total = 0
  for element in nested_list:
    if isinstance(element, list):
      total += sum_nested_list(element)
    else:
      total += element
  return total

# %%
nested_list = (1,2,[2,3],[5,6,4],7,8,[9,2,3,1])
result = sum_nested_list(nested_list)
print("Sum of nested list:", result)
# Out:
# Sum of nested list: 53

# %% [markdown]
# Task 2 - Generate All Permutations of a String:

# %%
def generate_permutation(s):
  permutation = []

  if len(s) <= 1:
    return [s]

  for i in range(len(s)):
    current_char = s[i]
    remaining_char = s[:i] + s[i+1:]

    for perm in generate_permutation(remaining_char):
      new_perm = current_char + perm
      permutation.append(new_perm)

  return permutation

# %%
print(generate_permutation("abc"))
print(generate_permutation("aab"))
# Out:
# ['abc', 'acb', 'bac', 'bca', 'cab', 'cba']
# ['aab', 'aba', 'aab', 'aba', 'baa', 'baa']

# %% [markdown]
# Task 3 - Directory Size Calculation:

# %%
def calculate_directory_size(directory_structure):
  total = 0

  for key, value in directory_structure.items():
    if isinstance(value, dict):
      total += calculate_directory_size(value)
    if isinstance(value, int):
      total += value

  return total

# %%
# Sample directory structure
directory_structure = {
"file1.txt": 200,
"file2.txt": 300,
"subdir1": {
"file3.txt": 400,
"file4.txt": 100
},
"subdir2": {
"subsubdir1": {
"file5.txt": 250
},
"file6.txt": 150
}
}
result = calculate_directory_size(directory_structure)
print("total size: ", result)
# Out:
# total size:  1400

# %% [markdown]
# #8.2.1 Exercises - Dynamic Programming:

# %% [markdown]
# Task 1 - Coin Change Problem:

# %%
def min_coins(coins,amount):
  if amount == 0:
    return 0
  dp = [float('inf')] * (amount + 1)
  dp[0] = 0
  for coin in coins:
    for i in range(coin, amount+1):
      dp[i] = min(dp[i], dp[i-coin]+1)

  return dp[amount] if dp[amount] != float('inf') else -1

# %%
print(min_coins([1,2,5], 11))
print(min_coins([5,5,1], 5))
# Out:
# 3
# 1

# %% [markdown]
# Task 2 - Longest Common Subsequence (LCS):

# %%
def longest_common_subsequence(s1,s2):
  m,n = len(s1), len(s2)
  dp = [[0] * (n+1) for _ in range(m+1)]

  for i in range(1, m+1):
    for j in range(1, n+1):
      if s1[i-1] == s2[j-1]:
        dp[i][j] = dp[i-1][j-1] + 1
      else:
        dp[i][j] = max(dp[i-1][j], dp[i][j-1])
  return dp[m][n]

# %%
print(longest_common_subsequence("abcde", "ace"))
# Out:
# 3

# %% [markdown]
# Task 3 - 0/1 Knapsack Problem:

# %%
def knapsack(weights, values, capacity):
  n = len(weights)
  dp = [[0] * (capacity + 1) for _ in range(n+1)]

  for i in range(1, n+1):
    for j in range(1, capacity+1):
      if weights[i-1] <= j:
        dp[i][j] = max(values[i-1] + dp[i-1][j - weights[i-1]], dp[i-1][j])
      else:
        dp[i][j] = dp[i-1][j]
  return dp[n][capacity]

# %%
weights = [1,3,4,5]
values =[1,4,5,7]
capacity = 7

print(knapsack(weights, values, capacity))
# Out:
# 9
